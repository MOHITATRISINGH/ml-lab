# %% [markdown]
# <a href="https://colab.research.google.com/github/MOHITATRISINGH/ml-lab/blob/main/ml_lab_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df = pd.read_excel('RESULT2.xlsx')
df
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4    ML Lab  \
# 0      S. No.   Internal   External      Total       Grde  Internal
# 1           1         37         36         73          F      25.5
# 2           2         61         75        136         B+      30.5
# 3           3         50         48         98          C        27
# 4           4         57         48        105          C        33
# ..        ...        ...        ...        ...        ...       ...
# 57         57         57         33         90          C      29.5
# 58         58         34         AB         34         AB      23.5
# 59         59         46         32         78          F      22.5
# 60         60         51         31         82          P        29
# 61         61         41         39         80          P        23
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8 Project Phase 1 Unnamed: 10 Unnamed: 11
# 0    External      Total       Grde        External       Total        Grde
# 1          28       53.5          C              36          36          B+
# 2          38       68.5         B+              41          41           A
# 3          32         59          B              37          37          B+
# 4          38         71         B+              37          37          B+
# ..        ...        ...        ...             ...         ...         ...
# 57         34       63.5          B              32          32           B
# 58         29       52.5          C              35          35          B+
# 59         32       54.5          C              35          35          B+
# 60         30         59          B              28          28           B
# 61         34         57          B              29          29           B
#
# [62 rows x 12 columns]

# %%
grade_mapping = {
    'O': 10, 'A+': 9, 'A': 8, 'B+': 7, 'B': 6,
    'C': 5, 'D': 4, 'F': 3,'AB':0,'P':4
}
df_encoded = df.copy()
import warnings

# Ignore future warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# Step 2: Make a copy to avoid modifying the original
df_encoded = df.copy()

# Step 3: Grade mapping
grade_mapping = {
    'O': 10,
    'A+': 9,
    'A': 8,
    'B+': 7,
    'B': 6,
    'C+': 5
}

# Step 4: Detect subject columns (exclude unnamed or ID/name columns)
subject_columns = [col for col in df.columns if not col.startswith('Unnamed') and col != 'Name']

# Step 5: Encode grades
for col in subject_columns:
    df_encoded[col] = df_encoded[col].map(grade_mapping).fillna(df_encoded[col])

# Step 6: Convert to numeric for mean calculation
for col in subject_columns:
    df_encoded[col] = pd.to_numeric(df_encoded[col], errors='coerce')

# Step 7: Calculate mean
df_encoded['Mean_Grade'] = df_encoded[subject_columns].mean(axis=1, skipna=True)

# Step 8: Classify based on mean
def classify(mean):
    if 9 <= mean <= 10:
        return 1
    elif 6 <= mean < 9:
        return 2
    elif 4 <= mean < 6:
        return 3
    else:
        return 4

df_encoded['Class'] = df_encoded['Mean_Grade'].apply(classify)

# Step 9: Save result locally (within Colab environment)
output_file = "modifygrade.xlsx"
df_encoded.to_excel(output_file, index=False)

# Step 10: Show result in notebook
df_encoded.head()  # Displays first few rows
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  ML Lab Unnamed: 6  \
# 0     S. No.   Internal   External      Total       Grde     NaN   External
# 1          1         37         36         73          F    25.5         28
# 2          2         61         75        136         B+    30.5         38
# 3          3         50         48         98          C    27.0         32
# 4          4         57         48        105          C    33.0         38
#
#   Unnamed: 7 Unnamed: 8  Project Phase 1 Unnamed: 10 Unnamed: 11  Mean_Grade  \
# 0      Total       Grde              NaN       Total        Grde         NaN
# 1       53.5          C             36.0          36          B+       30.75
# 2       68.5         B+             41.0          41           A       35.75
# 3         59          B             37.0          37          B+       32.00
# 4         71         B+             37.0          37          B+       35.00
#
#    Class
# 0      4
# 1      4
# 2      4
# 3      4
# 4      4

# %%
# Convert encoded grade columns to numeric
for col in subject_columns:
    df_encoded[col] = pd.to_numeric(df_encoded[col], errors='coerce')

# Calculate mean grade across subjects
df_encoded['Mean_Grade'] = df_encoded[subject_columns].mean(axis=1, skipna=True)

# Classify based on mean grade
def classify(mean):
    if 9 <= mean <= 10:
        return 1
    elif 6 <= mean < 9:
        return 2
    elif 4 <= mean < 6:
        return 3
    else:
        return 4

df_encoded['Class'] = df_encoded['Mean_Grade'].apply(classify)

# Save final file
final_file_path = "/content/Encoded_Grades.xlsx"
df_encoded.to_excel(final_file_path, index=False)

print(f"Final file with mean and class saved at: {final_file_path}")

# Display updated DataFrame
df_encoded.head()
# Out:
# Final file with mean and class saved at: /content/Encoded_Grades.xlsx
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  ML Lab Unnamed: 6  \
# 0     S. No.   Internal   External      Total       Grde     NaN   External
# 1          1         37         36         73          F    25.5         28
# 2          2         61         75        136         B+    30.5         38
# 3          3         50         48         98          C    27.0         32
# 4          4         57         48        105          C    33.0         38
#
#   Unnamed: 7 Unnamed: 8  Project Phase 1 Unnamed: 10 Unnamed: 11  Mean_Grade  \
# 0      Total       Grde              NaN       Total        Grde         NaN
# 1       53.5          C             36.0          36          B+       30.75
# 2       68.5         B+             41.0          41           A       35.75
# 3         59          B             37.0          37          B+       32.00
# 4         71         B+             37.0          37          B+       35.00
#
#    Class
# 0      4
# 1      4
# 2      4
# 3      4
# 4      4

# %%
counts = df_encoded['Class'].value_counts().sort_index()

# Print the counts
print("Classes Distribution:")
for class_label, count in counts.items():
    print(f"Class {class_label}: {count} students")
# Out:
# Classes Distribution:
# Class 4: 62 students
